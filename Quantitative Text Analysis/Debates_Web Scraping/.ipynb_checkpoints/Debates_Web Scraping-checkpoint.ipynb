# %% [markdown]
# # Text Preparation
#
# ## Overview
#
# This code collects and prepares textual data for
# analysis. As the data source we will debates in the Dáil Éireann (Irish
# Parliament) for the first 2 months of 2025.
#
# ## Part 1: Data Acquisition
#
# In this part a scraper is used that collects the data using the Oireachtas API.
# The data is collected for the first 2 months of 2025 (January and
# February, but the bulk of the debates are in February).
#
# ## Part 2: Text Preprocessing
#
# In this part the code cleans up the collected data.
#
# The ultimate goal is to have a dataset of the following form:
#
# | dail | vol | no  | date | speaker | text | ntokens | ntypes |
# |------|-----|-----|------|---------|------|---------|--------|
#
# where:
#
# `dail` - is the number of the Dáil (e.g. 34th Dáil)
#
# `vol` - is the volume number of the debates (e.g. 1000)
#
# `no` - is the number of the debate in the volume (e.g. 1)
#
# `date` - is the date of the debate (in YYYY-MM-DD form, e.g. 2025-01-01)
#
# `speaker` - is the name of the speaker
#
# `text` - is the text of the speech
#
# `ntokens` - is the number of tokens in the speech
#
# `ntypes` - is the number of types in the speech

# %%
# Installing necessary packages 
#install.packages("httr")
#install.packages("httr2")
#install.packages("jsonlite")
#install.packages("stopwords")
library(xml2) 
library(httr)  
library(httr2)
library(jsonlite)
library(tidyverse)
library(dplyr)
library(tidytext)
library(stringr)
library(stopwords)

# %%
## Part 1: Data Acquisition

# Defining the URL for the API
base_url <- "https://api.oireachtas.ie/v1/debates"

# Defining the query parameters
date_start <- "2025-01-01"  
date_end <- "2025-02-28"    

# API request with query parameters
response <- request(base_url) %>%
  req_url_query(date_start = date_start, date_end = date_end) %>%
  req_perform()

# Checking the response status and print error
if (resp_status(response) == 200) {
  parsed_json_data <- response %>% resp_body_json() 
  parsed_json_data%>% glimpse()
} else {
  content <- response %>% resp_body_string()
  cat(content)
}

# printing the result 
parsed_json_data
# Out:
# List of 2
#  $ head   :List of 3
#   ..$ counts   :List of 2
#   .. ..$ debateCount: int 20
#   .. ..$ resultCount: int 20
#   ..$ dateRange:List of 2
#   .. ..$ start: chr "2025-01-01T00:00:00.000Z"
#   .. ..$ end  : chr "2025-02-28T00:00:00.000Z"
#   ..$ lang     : chr "mul"
#  $ results:List of 20
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-27"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-27"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-26"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-26"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-25"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-25"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-20"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-19"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-19"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-19"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-18"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-13"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-13"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-12"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-12"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-11"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-06"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-02-05"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-01-23"
#   ..$ :List of 2
#   .. ..$ debateRecord:List of 9
#   .. ..$ contextDate : chr "2025-01-22"
# $head
# $head$counts
# $head$counts$debateCount
# [1] 20
#
# $head$counts$resultCount
# [1] 20
#
#
# $head$dateRange
# $head$dateRange$start
# [1] "2025-01-01T00:00:00.000Z"
#
# $head$dateRange$end
# [1] "2025-02-28T00:00:00.000Z"
#
#
# $head$lang
# [1] "mul"
#
#
# $results
# $results[[1]]
# $results[[1]]$debateRecord
# $results[[1]]$debateRecord$debateSections
# $results[[1]]$debateRecord$debateSections[[1]]
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$showAs
# [1] "Gnó an tSeanaid - Business of Seanad"
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$parentDebateSection
# NULL
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$counts$speakerCount
# [1] 1
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$counts$speechCount
# [1] 1
#
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[1]]$debateRecord$debateSections[[1]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_2"
#
#
#
# $results[[1]]$debateRecord$debateSections[[2]]
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$showAs
# [1] "Nithe i dtosach suíonna - Commencement Matters"
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection
# NULL
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$counts$speakerCount
# [1] 1
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$counts$speechCount
# [1] 1
#
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[1]]$debateRecord$debateSections[[2]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_3"
#
#
#
# $results[[1]]$debateRecord$debateSections[[3]]
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$showAs
# [1] "Domestic Pets"
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$formats
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$showAs
# [1] "Nithe i dtosach suíonna - Commencement Matters"
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_3"
#
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$debateSectionId
# [1] "dbsect_4"
#
# $results[[1]]$debateRecord$debateSections[[3]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_4"
#
#
#
# $results[[1]]$debateRecord$debateSections[[4]]
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$showAs
# [1] "Civil Registration Service"
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$formats
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$showAs
# [1] "Nithe i dtosach suíonna - Commencement Matters"
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_3"
#
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$counts$speakerCount
# [1] 3
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$debateSectionId
# [1] "dbsect_5"
#
# $results[[1]]$debateRecord$debateSections[[4]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_5"
#
#
#
# $results[[1]]$debateRecord$debateSections[[5]]
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$showAs
# [1] "National Planning Framework"
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$formats
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$showAs
# [1] "Nithe i dtosach suíonna - Commencement Matters"
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_3"
#
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$counts$speakerCount
# [1] 3
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$counts$speechCount
# [1] 5
#
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$debateSectionId
# [1] "dbsect_6"
#
# $results[[1]]$debateRecord$debateSections[[5]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_6"
#
#
#
# $results[[1]]$debateRecord$debateSections[[6]]
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$showAs
# [1] "Housing Provision"
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$formats
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$showAs
# [1] "Nithe i dtosach suíonna - Commencement Matters"
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_3"
#
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$counts$speakerCount
# [1] 3
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$counts$speechCount
# [1] 5
#
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$debateSectionId
# [1] "dbsect_7"
#
# $results[[1]]$debateRecord$debateSections[[6]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_7"
#
#
#
# $results[[1]]$debateRecord$debateSections[[7]]
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$showAs
# [1] "School Accommodation"
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection$formats
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection$showAs
# [1] "Nithe i dtosach suíonna - Commencement Matters"
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_3"
#
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$counts$speakerCount
# [1] 3
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$counts$speechCount
# [1] 5
#
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$debateSectionId
# [1] "dbsect_8"
#
# $results[[1]]$debateRecord$debateSections[[7]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_8"
#
#
#
# $results[[1]]$debateRecord$debateSections[[8]]
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$showAs
# [1] "Emergency Departments"
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$formats
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$showAs
# [1] "Nithe i dtosach suíonna - Commencement Matters"
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_3"
#
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$counts$speechCount
# [1] 4
#
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$debateSectionId
# [1] "dbsect_9"
#
# $results[[1]]$debateRecord$debateSections[[8]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_9"
#
#
#
# $results[[1]]$debateRecord$debateSections[[9]]
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$showAs
# [1] "Visit of Bulgarian Ambassador"
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection
# NULL
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$counts$speakerCount
# [1] 1
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$counts$speechCount
# [1] 1
#
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$debateSectionId
# [1] "dbsect_10"
#
# $results[[1]]$debateRecord$debateSections[[9]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_10"
#
#
#
# $results[[1]]$debateRecord$debateSections[[10]]
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$debateType
# [1] "orderofBusiness"
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$showAs
# [1] "An tOrd Gnó - Order of Business"
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection
# NULL
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$counts$speakerCount
# [1] 16
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$counts$speechCount
# [1] 33
#
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$bill
# NULL
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$debateSectionId
# [1] "dbsect_11"
#
# $results[[1]]$debateRecord$debateSections[[10]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_11"
#
#
#
# $results[[1]]$debateRecord$debateSections[[11]]
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$formats
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$formats$pdf
# NULL
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$formats$xml
# NULL
#
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$showAs
# [1] "Statute Law Revision Bill 2024: Committee Stage"
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection
# NULL
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$counts
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$counts$speakerCount
# [1] 4
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$counts$speechCount
# [1] 35
#
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$speakers
# list()
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill$event
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill$event$isBillStage
# [1] TRUE
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill$event$showAs
# [1] "Statute Law Revision Bill 2024: Committee Stage (Seanad)"
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill$event$stage
# [1] "3"
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill$event$houseCode
# [1] "seanad"
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill$event$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/bill/2024/78/seanad/3"
#
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$bill$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/bill/2024/78"
#
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$debateSectionId
# [1] "dbsect_12"
#
# $results[[1]]$debateRecord$debateSections[[11]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/dbsect_12"
#
#
#
#
# $results[[1]]$debateRecord$date
# [1] "2025-02-27"
#
# $results[[1]]$debateRecord$lastUpdated
# [1] "2025-03-04T02:41:02+00:00"
#
# $results[[1]]$debateRecord$debateType
# [1] "debate"
#
# $results[[1]]$debateRecord$formats
# $results[[1]]$debateRecord$formats$pdf
# $results[[1]]$debateRecord$formats$pdf$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/debateRecord/seanad/2025-02-27/debate/mul@/main.pdf"
#
#
# $results[[1]]$debateRecord$formats$xml
# $results[[1]]$debateRecord$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/mul@/main.xml"
#
#
# $results[[1]]$debateRecord$formats$writtens_pdf
# NULL
#
#
# $results[[1]]$debateRecord$chamber
# $results[[1]]$debateRecord$chamber$showAs
# [1] "Seanad Éireann"
#
# $results[[1]]$debateRecord$chamber$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/def/house/seanad"
#
#
# $results[[1]]$debateRecord$counts
# $results[[1]]$debateRecord$counts$questionCount
# [1] 0
#
# $results[[1]]$debateRecord$counts$billCount
# [1] 1
#
# $results[[1]]$debateRecord$counts$contributorCount
# [1] 25
#
# $results[[1]]$debateRecord$counts$divisionCount
# [1] 0
#
# $results[[1]]$debateRecord$counts$debateSectionCount
# [1] 11
#
#
# $results[[1]]$debateRecord$house
# $results[[1]]$debateRecord$house$showAs
# [1] "27th Seanad"
#
# $results[[1]]$debateRecord$house$chamberType
# [1] "house"
#
# $results[[1]]$debateRecord$house$committeeCode
# [1] ""
#
# $results[[1]]$debateRecord$house$houseCode
# [1] "seanad"
#
# $results[[1]]$debateRecord$house$houseNo
# [1] "27"
#
# $results[[1]]$debateRecord$house$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/house/seanad/27"
#
#
# $results[[1]]$debateRecord$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/seanad/2025-02-27/debate/main"
#
#
# $results[[1]]$contextDate
# [1] "2025-02-27"
#
#
# $results[[2]]
# $results[[2]]$debateRecord
# $results[[2]]$debateRecord$date
# [1] "2025-02-27"
#
# $results[[2]]$debateRecord$debateSections
# $results[[2]]$debateRecord$debateSections[[1]]
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$debateType
# [1] "questions"
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$containsDebate
# [1] FALSE
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$showAs
# [1] "Ceisteanna ar Sonraíodh Uain Dóibh - Priority Questions"
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$parentDebateSection
# NULL
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$counts$speakerCount
# [1] 0
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$counts$speechCount
# [1] 0
#
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[1]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_2"
#
#
#
# $results[[2]]$debateRecord$debateSections[[2]]
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_3.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$showAs
# [1] "School Curriculum"
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna ar Sonraíodh Uain Dóibh - Priority Questions"
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_2"
#
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[2]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_3"
#
#
#
# $results[[2]]$debateRecord$debateSections[[3]]
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_4.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$showAs
# [1] "School Accommodation"
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna ar Sonraíodh Uain Dóibh - Priority Questions"
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_2"
#
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$counts$speakerCount
# [1] 3
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$counts$speechCount
# [1] 9
#
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$debateSectionId
# [1] "dbsect_4"
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[3]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_4"
#
#
#
# $results[[2]]$debateRecord$debateSections[[4]]
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_5.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$showAs
# [1] "Special Educational Needs"
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna ar Sonraíodh Uain Dóibh - Priority Questions"
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_2"
#
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$debateSectionId
# [1] "dbsect_5"
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[4]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_5"
#
#
#
# $results[[2]]$debateRecord$debateSections[[5]]
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_6.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$showAs
# [1] "Special Educational Needs"
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna ar Sonraíodh Uain Dóibh - Priority Questions"
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_2"
#
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$counts$speechCount
# [1] 8
#
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$debateSectionId
# [1] "dbsect_6"
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[5]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_6"
#
#
#
# $results[[2]]$debateRecord$debateSections[[6]]
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_7.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$showAs
# [1] "School Staff"
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna ar Sonraíodh Uain Dóibh - Priority Questions"
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_2"
#
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$debateSectionId
# [1] "dbsect_7"
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[6]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_7"
#
#
#
# $results[[2]]$debateRecord$debateSections[[7]]
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$debateType
# [1] "questions"
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$containsDebate
# [1] FALSE
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$showAs
# [1] "Ceisteanna Eile - Other Questions"
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$parentDebateSection
# NULL
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$counts$speakerCount
# [1] 0
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$counts$speechCount
# [1] 0
#
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$debateSectionId
# [1] "dbsect_8"
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[7]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_8"
#
#
#
# $results[[2]]$debateRecord$debateSections[[8]]
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_9.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$showAs
# [1] "School Accommodation"
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna Eile - Other Questions"
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_8"
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_8"
#
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$debateSectionId
# [1] "dbsect_9"
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[8]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_9"
#
#
#
# $results[[2]]$debateRecord$debateSections[[9]]
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_10.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$showAs
# [1] "Education Welfare Service"
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna Eile - Other Questions"
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_8"
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_8"
#
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$debateSectionId
# [1] "dbsect_10"
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[9]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_10"
#
#
#
# $results[[2]]$debateRecord$debateSections[[10]]
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_11.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$showAs
# [1] "Education Policy"
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna Eile - Other Questions"
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_8"
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_8"
#
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$debateSectionId
# [1] "dbsect_11"
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[10]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_11"
#
#
#
# $results[[2]]$debateRecord$debateSections[[11]]
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_12.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$showAs
# [1] "School Accommodation"
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection$showAs
# [1] "Ceisteanna Eile - Other Questions"
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection$debateSectionId
# [1] "dbsect_8"
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$parentDebateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_8"
#
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$counts
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$counts$speakerCount
# [1] 2
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$counts$speechCount
# [1] 6
#
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$speakers
# list()
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$debateSectionId
# [1] "dbsect_12"
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$bill
# NULL
#
# $results[[2]]$debateRecord$debateSections[[11]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/dbsect_12"
#
#
#
# $results[[2]]$debateRecord$debateSections[[12]]
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$debateType
# [1] "question"
#
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$formats
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$formats$xml
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-27/debate/mul@/dbsect_13.xml"
#
#
#
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$showAs
# [1] "Scoileanna Gaeilge agus Gaeltachta"
#
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$parentDebateSection
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$parentDebateSection$formats
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$parentDebateSection$formats$pdf
# NULL
#
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$parentDebateSection$formats$xml
# NULL
#
#
# $results[[2]]$debateRecord$debateSections[[12]]$debateSection$parentDebateSection$showAs
# ...
# $results[[18]]$debateRecord$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-05/debate/mul@/main.xml"
#
#
# $results[[18]]$debateRecord$formats$writtens_pdf
# NULL
#
#
# $results[[18]]$debateRecord$chamber
# $results[[18]]$debateRecord$chamber$showAs
# [1] "Dáil Éireann"
#
# $results[[18]]$debateRecord$chamber$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/def/house/dail"
#
#
# $results[[18]]$debateRecord$counts
# $results[[18]]$debateRecord$counts$questionCount
# [1] 0
#
# $results[[18]]$debateRecord$counts$billCount
# [1] 0
#
# $results[[18]]$debateRecord$counts$divisionCount
# [1] 2
#
# $results[[18]]$debateRecord$counts$contributorCount
# [1] 173
#
# $results[[18]]$debateRecord$counts$debateSectionCount
# [1] 15
#
#
# $results[[18]]$debateRecord$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-02-05/debate/main"
#
# $results[[18]]$debateRecord$house
# $results[[18]]$debateRecord$house$showAs
# [1] "34th Dáil"
#
# $results[[18]]$debateRecord$house$committeeCode
# [1] ""
#
# $results[[18]]$debateRecord$house$chamberType
# [1] "house"
#
# $results[[18]]$debateRecord$house$houseCode
# [1] "dail"
#
# $results[[18]]$debateRecord$house$houseNo
# [1] "34"
#
# $results[[18]]$debateRecord$house$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/house/dail/34"
#
#
#
# $results[[18]]$contextDate
# [1] "2025-02-05"
#
#
# $results[[19]]
# $results[[19]]$debateRecord
# $results[[19]]$debateRecord$debateSections
# $results[[19]]$debateRecord$debateSections[[1]]
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$debateType
# [1] "debate"
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$formats
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$formats$pdf
# NULL
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$formats$xml
# NULL
#
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$showAs
# [1] "Gnó na Dála - Business of Dáil"
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$parentDebateSection
# NULL
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$counts
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$counts$speakerCount
# [1] 9
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$counts$speechCount
# [1] 25
#
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$speakers
# list()
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$bill
# NULL
#
# $results[[19]]$debateRecord$debateSections[[1]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/dbsect_2"
#
#
#
# $results[[19]]$debateRecord$debateSections[[2]]
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$debateType
# [1] "debate"
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$formats
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$formats$pdf
# NULL
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$formats$xml
# NULL
#
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$showAs
# [1] "Taoiseach a Ainmniú (Atógáil) - Nomination of Taoiseach (Resumed)"
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection
# NULL
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$counts
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$counts$speakerCount
# [1] 24
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$counts$speechCount
# [1] 69
#
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$speakers
# list()
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$debateSectionId
# [1] "dbsect_7"
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$bill
# NULL
#
# $results[[19]]$debateRecord$debateSections[[2]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/dbsect_7"
#
#
#
# $results[[19]]$debateRecord$debateSections[[3]]
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$debateType
# [1] "debate"
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$formats
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$formats$pdf
# NULL
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$formats$xml
# NULL
#
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$showAs
# [1] "Ceapachán an Taoisigh agus Ainmniú Chomhaltaí an Rialtais"
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$containsDebate
# [1] FALSE
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$parentDebateSection
# NULL
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$counts
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$counts$speakerCount
# [1] 0
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$counts$speechCount
# [1] 0
#
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$speakers
# list()
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$debateSectionId
# [1] "dbsect_12"
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$bill
# NULL
#
# $results[[19]]$debateRecord$debateSections[[3]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/dbsect_12"
#
#
#
# $results[[19]]$debateRecord$debateSections[[4]]
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$debateType
# [1] "debate"
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$formats
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$formats$pdf
# NULL
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$formats$xml
# NULL
#
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$showAs
# [1] "Appointment of Taoiseach and Nomination of Members of Government"
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$parentDebateSection
# NULL
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$counts
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$counts$speakerCount
# [1] 19
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$counts$speechCount
# [1] 36
#
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$speakers
# list()
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$debateSectionId
# [1] "dbsect_13"
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$bill
# NULL
#
# $results[[19]]$debateRecord$debateSections[[4]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/dbsect_13"
#
#
#
# $results[[19]]$debateRecord$debateSections[[5]]
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$debateType
# [1] "motion"
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$formats
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$formats$pdf
# NULL
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$formats$xml
# NULL
#
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$showAs
# [1] "Select Committee on Subsidiarity (European Union Legislative Scrutiny): Motion"
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$parentDebateSection
# NULL
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$counts
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$counts$speakerCount
# [1] 1
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$counts$speechCount
# [1] 1
#
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$speakers
# list()
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$debateSectionId
# [1] "dbsect_18"
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$bill
# NULL
#
# $results[[19]]$debateRecord$debateSections[[5]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/dbsect_18"
#
#
#
# $results[[19]]$debateRecord$debateSections[[6]]
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$debateType
# [1] "motion"
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$formats
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$formats$pdf
# NULL
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$formats$xml
# NULL
#
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$showAs
# [1] "Committee on Standing Orders and Dáil Reform: Motion"
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$parentDebateSection
# NULL
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$counts
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$counts$speakerCount
# [1] 1
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$counts$speechCount
# [1] 1
#
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$speakers
# list()
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$debateSectionId
# [1] "dbsect_19"
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$bill
# NULL
#
# $results[[19]]$debateRecord$debateSections[[6]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/dbsect_19"
#
#
#
#
# $results[[19]]$debateRecord$date
# [1] "2025-01-23"
#
# $results[[19]]$debateRecord$lastUpdated
# [1] "2025-02-07T02:36:52+00:00"
#
# $results[[19]]$debateRecord$debateType
# [1] "debate"
#
# $results[[19]]$debateRecord$formats
# $results[[19]]$debateRecord$formats$pdf
# $results[[19]]$debateRecord$formats$pdf$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/debateRecord/dail/2025-01-23/debate/mul@/main.pdf"
#
#
# $results[[19]]$debateRecord$formats$xml
# $results[[19]]$debateRecord$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/mul@/main.xml"
#
#
# $results[[19]]$debateRecord$formats$writtens_pdf
# NULL
#
#
# $results[[19]]$debateRecord$chamber
# $results[[19]]$debateRecord$chamber$showAs
# [1] "Dáil Éireann"
#
# $results[[19]]$debateRecord$chamber$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/def/house/dail"
#
#
# $results[[19]]$debateRecord$counts
# $results[[19]]$debateRecord$counts$questionCount
# [1] 0
#
# $results[[19]]$debateRecord$counts$billCount
# [1] 0
#
# $results[[19]]$debateRecord$counts$contributorCount
# [1] 173
#
# $results[[19]]$debateRecord$counts$divisionCount
# [1] 3
#
# $results[[19]]$debateRecord$counts$debateSectionCount
# [1] 6
#
#
# $results[[19]]$debateRecord$house
# $results[[19]]$debateRecord$house$showAs
# [1] "34th Dáil"
#
# $results[[19]]$debateRecord$house$committeeCode
# [1] ""
#
# $results[[19]]$debateRecord$house$chamberType
# [1] "house"
#
# $results[[19]]$debateRecord$house$houseCode
# [1] "dail"
#
# $results[[19]]$debateRecord$house$houseNo
# [1] "34"
#
# $results[[19]]$debateRecord$house$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/house/dail/34"
#
#
# $results[[19]]$debateRecord$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-23/debate/main"
#
#
# $results[[19]]$contextDate
# [1] "2025-01-23"
#
#
# $results[[20]]
# $results[[20]]$debateRecord
# $results[[20]]$debateRecord$debateSections
# $results[[20]]$debateRecord$debateSections[[1]]
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$debateType
# [1] "debate"
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$formats
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$formats$pdf
# NULL
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$formats$xml
# NULL
#
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$showAs
# [1] "Gnó na Dála - Business of Dáil"
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$parentDebateSection
# NULL
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$counts
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$counts$speakerCount
# [1] 24
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$counts$speechCount
# [1] 198
#
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$speakers
# list()
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$debateSectionId
# [1] "dbsect_2"
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$bill
# NULL
#
# $results[[20]]$debateRecord$debateSections[[1]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-22/debate/dbsect_2"
#
#
#
# $results[[20]]$debateRecord$debateSections[[2]]
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$debateType
# [1] "debate"
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$formats
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$formats$pdf
# NULL
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$formats$xml
# NULL
#
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$showAs
# [1] "Taoiseach a Ainmniú - Nomination of Taoiseach"
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$containsDebate
# [1] TRUE
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$parentDebateSection
# NULL
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$counts
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$counts$speakerCount
# [1] 7
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$counts$speechCount
# [1] 27
#
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$speakers
# list()
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$debateSectionId
# [1] "dbsect_3"
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$bill
# NULL
#
# $results[[20]]$debateRecord$debateSections[[2]]$debateSection$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-22/debate/dbsect_3"
#
#
#
#
# $results[[20]]$debateRecord$date
# [1] "2025-01-22"
#
# $results[[20]]$debateRecord$lastUpdated
# [1] "2025-03-19T02:52:11+00:00"
#
# $results[[20]]$debateRecord$debateType
# [1] "debate"
#
# $results[[20]]$debateRecord$formats
# $results[[20]]$debateRecord$formats$pdf
# $results[[20]]$debateRecord$formats$pdf$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/debateRecord/dail/2025-01-22/debate/mul@/main.pdf"
#
#
# $results[[20]]$debateRecord$formats$xml
# $results[[20]]$debateRecord$formats$xml$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-22/debate/mul@/main.xml"
#
#
# $results[[20]]$debateRecord$formats$writtens_pdf
# NULL
#
#
# $results[[20]]$debateRecord$chamber
# $results[[20]]$debateRecord$chamber$showAs
# [1] "Dáil Éireann"
#
# $results[[20]]$debateRecord$chamber$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/def/house/dail"
#
#
# $results[[20]]$debateRecord$counts
# $results[[20]]$debateRecord$counts$questionCount
# [1] 0
#
# $results[[20]]$debateRecord$counts$billCount
# [1] 0
#
# $results[[20]]$debateRecord$counts$divisionCount
# [1] 0
#
# $results[[20]]$debateRecord$counts$contributorCount
# [1] 135
#
# $results[[20]]$debateRecord$counts$debateSectionCount
# [1] 2
#
#
# $results[[20]]$debateRecord$uri
# [1] "https://data.oireachtas.ie/akn/ie/debateRecord/dail/2025-01-22/debate/main"
#
# $results[[20]]$debateRecord$house
# $results[[20]]$debateRecord$house$showAs
# [1] "34th Dáil"
#
# $results[[20]]$debateRecord$house$committeeCode
# [1] ""
#
# $results[[20]]$debateRecord$house$chamberType
# [1] "house"
#
# $results[[20]]$debateRecord$house$houseCode
# [1] "dail"
#
# $results[[20]]$debateRecord$house$houseNo
# [1] "34"
#
# $results[[20]]$debateRecord$house$uri
# [1] "https://data.oireachtas.ie/ie/oireachtas/house/dail/34"
#
#
#
# $results[[20]]$contextDate
# [1] "2025-01-22"

# %%
# Extracting debate information from a single debate record
extract_debate_info <- function(debateRecord) {    
  # Extracting metadata from the debate record
  date <- debateRecord$debateRecord$date
  house_code <- debateRecord$debateRecord$house$houseCode
  chamber_showAs <- debateRecord$debateRecord$chamber$showAs
  dail <- debateRecord$debateRecord$house$showAs
  xml_url <- debateRecord$debateRecord$formats$xml$uri
  pdf_url <- debateRecord$debateRecord$formats$pdf$uri
  
  # Processing nested debate sections, if present
  debate_sections <- debateRecord$debateRecord$debateSections
  if (length(debate_sections) > 0) {
    sections_info <- map_df(debate_sections, function(section) {
      debate_type <- section$debateSection$debateType
      debate_text <- section$debateSection$text[[1]]$text
      speech_count <- section$debateSection$counts$speechCount
      speaker_count <- section$debateSection$counts$speakerCount
      debate_section_title <- section$debateSection$showAs
      
      # Creating a tibble with extracted debate section data
      tibble(
        date = date,
        house_code = house_code,
        chamber_showAs = chamber_showAs,
        dail = dail,
        xml_url = xml_url,
        pdf_url = pdf_url,
        debate_type = debate_type,
        debate_text = debate_text,
        speech_count = speech_count,
        speaker_count = speaker_count,
        debate_section_title = debate_section_title
      )
    })
    return(sections_info)
  } else {
    return(tibble(
      date = date,
      house_code = house_code,
      chamber_showAs = chamber_showAs,
      dail = dail,
      xml_url = xml_url,
      pdf_url = pdf_url,
      debate_type = NA,
      debate_text = NA,
      speech_count = NA,
      speaker_count = NA,
      debate_section_title = NA
    ))
  }
}

# Applying the extraction function to each debateRecord in the 'results'
debates_df <- map_df(parsed_json_data$results, extract_debate_info)

# Viewing and exploring the extracted data
print(debates_df)
#table(debates_df$date)
#table(debates_df$house_code)
#table(debates_df$chamber_showAs)
#table(debates_df$dail)
#table(debates_df$debate_type)
# Out:
# # A tibble: 344 × 10
#    date       house_code chamber_showAs dail        xml_url  pdf_url debate_type
#    <chr>      <chr>      <chr>          <chr>       <chr>    <chr>   <chr>
#  1 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  2 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  3 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  4 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  5 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  6 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  7 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  8 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
#  9 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… debate
# 10 2025-02-27 seanad     Seanad Éireann 27th Seanad https:/… https:… orderofBus…
# # ℹ 334 more rows
# # ℹ 3 more variables: speech_count <int>, speaker_count <int>,
# #   debate_section_title <chr>

# %%
# Parsing XML content and combining preface and debate data
parse_debate_xml <- function(xml_url, dail) {
  
  # Downloading XML from URL
  xml_content <- GET(xml_url)
  
  # Parsing the XML content
  xml_data <- read_xml(content(xml_content, as = "text", encoding = "UTF-8"))
  
  # Defining the XML namespace
  ns <- xml_ns_rename(xml_ns(xml_data), d1 = "akn")
  
  # Extracting values from <preface> block elements
  date_en <- xml_text(xml_find_first(xml_data, ".//akn:block[@name='date_en']/akn:docDate", ns))
  volume <- xml_text(xml_find_first(xml_data, ".//akn:block[@name='volume']/akn:docNumber", ns))
  number <- xml_text(xml_find_first(xml_data, ".//akn:block[@name='number']/akn:docNumber", ns))
  
  # Storing preface information in a data frame
  preface_df <- tibble(
    date_en = date_en,
    volume = volume,
    number = number
  )
  
  # Extracting values from <debateBody> 
  debate_sections <- xml_find_all(xml_data, ".//akn:debateSection", ns)
  debate_list <- lapply(debate_sections, function(section) {
    heading <- xml_text(xml_find_first(section, "akn:heading", ns))
    speeches <- xml_find_all(section, "akn:speech", ns)
    
    # Extracting all speeches and their paragraph information
    speech_data <- lapply(speeches, function(speech) {
      speaker <- xml_attr(speech, "by")
      paragraphs <- xml_text(xml_find_all(speech, "akn:p", ns))
      combined_paragraphs <- paste(paragraphs, collapse = " ")
      
      # Returning a tibble for each speech
      tibble(
        speaker = speaker,
        speech = combined_paragraphs
      )
    })
    
    # Combining all speech data into one data frame
    bind_rows(speech_data)
  })
  
  # Combining all debate sections into one data frame
  debate_df <- bind_rows(debate_list)
  
  # Adding preface data (date, volume, and number) and XML URL & Dail info 
  combined_df <- debate_df %>%
    mutate(
      date_en = preface_df$date_en,
      volume = preface_df$volume,
      number = preface_df$number,
      xml_url = xml_url,  # OPTIONAL
      dail = dail        
    )
  
  combined_df
}

# Filtering out ONLY debates related to "dail"
url_data <- debates_df %>% 
  filter(house_code == "dail") %>% 
  select(xml_url,dail) %>% distinct()

# Initializing an empty data frame to store the final combined data
final_combined_df <- tibble()

# Iterating through the XML URLs and parsing each file, passing xml_url and dail
for (i in seq_len(nrow(url_data))) {
  dail_value <- url_data$dail[i]
  
  combined_data <- suppressWarnings(parse_debate_xml(url_data$xml_url[i], dail_value)) %>%
    select(-xml_url) 
  
  final_combined_df <- bind_rows(final_combined_df, combined_data)
}

# Printing the final combined data frame
print(final_combined_df)
# Out:
# # A tibble: 4,571 × 6
#    speaker        speech                             date_en volume number dail
#    <chr>          <chr>                              <chr>   <chr>  <chr>  <chr>
#  1 #DarrenORourke As this is the first ministerial … Thursd… Vol. … No. 6  34th…
#  2 #HelenMcEntee  I look forward to working with al… Thursd… Vol. … No. 6  34th…
#  3 #DarrenORourke I welcome the fact that the Minis… Thursd… Vol. … No. 6  34th…
#  4 #HelenMcEntee  I think our stakeholders have out… Thursd… Vol. … No. 6  34th…
#  5 #DarrenORourke We have spent more time identifyi… Thursd… Vol. … No. 6  34th…
#  6 #HelenMcEntee  The most important thing here is … Thursd… Vol. … No. 6  34th…
#  7 #RuthCoppinger I know the Minister is new to her… Thursd… Vol. … No. 6  34th…
#  8 #HelenMcEntee  I thank the Deputy for raising th… Thursd… Vol. … No. 6  34th…
#  9 #RuthCoppinger The reality is that both areas ne… Thursd… Vol. … No. 6  34th…
# 10 #HelenMcEntee  I will outline the capacity that … Thursd… Vol. … No. 6  34th…
# # ℹ 4,561 more rows

# %%
# Viewing and exploring the extracted combined data
#head(final_combined_df)
#table(final_combined_df$speaker)
#table(final_combined_df$date_en)
#table(final_combined_df$volume)
#table(final_combined_df$number)
#table(final_combined_df$dail)

# %%
## Part 2: Text Preprocessing

# Computing ntokens and ntypes
calculate_tokens_types <- function(speech_text) {
  if (is.na(speech_text) || speech_text == "") {
    return(tibble(ntokens = 0, ntypes = 0))
  }
  clean_text <- str_to_lower(speech_text) %>%
    str_replace_all("[^a-z\\s]", "")
  words <- str_split(clean_text, "\\s+")[[1]]
  words <- words[words != "" & !(words %in% stopwords("en"))]  # OPTIONAL 
  tibble(ntokens = length(words), ntypes = length(unique(words)))
}

# Viewing the results 
#summary(final_combined_df %>% select(ntokens, ntypes))

# Note: Stopwords are also removed 

# Cleaning speaker names 
split_name <- function(speaker) {
  gsub("([a-z])([A-Z])", "\\1 \\2", gsub("^#", "", speaker))
}

# Cleaning and preprocessing data - volume, number, speaker 
final_combined_df <- final_combined_df %>%
  mutate(
    speaker = split_name(speaker),
    volume = str_replace(volume, "^Vol\\.\\s*", ""),
    number = str_replace(number, "^No\\.\\s*", "")
  ) %>%
  rowwise() %>%
  mutate(tokens_info = calculate_tokens_types(speech)) %>%
  mutate(ntokens = tokens_info$ntokens, ntypes = tokens_info$ntypes) %>%
  select(-tokens_info) %>%
  ungroup()

# Printing first and last 5 rows
print(head(final_combined_df, 5))
print(tail(final_combined_df, 5))

# Printing dataset dimensions
print(dim(final_combined_df))

# Counting unique speakers
unique_speakers <- final_combined_df %>%
  filter(speaker != "") %>%
  distinct(speaker) %>%
  nrow()
print(paste("Total unique speakers:", unique_speakers))

# Note: There are some missing values in volume and number and speakers (38 missing - no name after #).
# Out:
# # A tibble: 5 × 8
#   speaker        speech               date_en volume number dail  ntokens ntypes
#   <chr>          <chr>                <chr>   <chr>  <chr>  <chr>   <int>  <int>
# 1 Darren ORourke As this is the firs… Thursd… 1063   6      34th…      40     35
# 2 Helen Mc Entee I look forward to w… Thursd… 1063   6      34th…     185    134
# 3 Darren ORourke I welcome the fact … Thursd… 1063   6      34th…      53     45
# 4 Helen Mc Entee I think our stakeho… Thursd… 1063   6      34th…     116     91
# 5 Darren ORourke We have spent more … Thursd… 1063   6      34th…      58     49
# # A tibble: 5 × 8
#   speaker                 speech      date_en volume number dail  ntokens ntypes
#   <chr>                   <chr>       <chr>   <chr>  <chr>  <chr>   <int>  <int>
# 1 ""                      You are no… Wednes… 1062   2      34th…       5      5
# 2 "Pearse Doherty"        No way.     Wednes… 1062   2      34th…       1      1
# 3 "Padraig Mac Lochlainn" Outrageous… Wednes… 1062   2      34th…       8      7
# 4 "Albert Dolan"          Deputy Mar… Wednes… 1062   2      34th…       4      4
# 5 "Verona Murphy"         I am adjou… Wednes… 1062   2      34th…       5      5
# [1] 4571    8
# [1] "Total unique speakers: 166"
